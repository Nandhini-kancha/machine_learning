# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
url="https://news.ycombinator.com/"
response=requests.get(url,verify=False)
soup=BeautifulSoup(response.text,"html.parser")
headlines=soup.find_all("span",class_="titleline")
with open("headlines.csv","w",newline="",encoding="utf-8") as file:
    writer=csv.writer(file)
    writer.writerow(["headline"])

    for h in headlines:
        writer.writerow([h.text])
print("Data saved to headlines.csv")
# Out:
# C:\Users\Nandhini\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'news.ycombinator.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Data saved to headlines.csv

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Nandhini\machinelearning
